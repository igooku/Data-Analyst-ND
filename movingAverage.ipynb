# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
cityResults = pd.read_csv('results-3.csv')
globalResults = pd.read_csv('results-2.csv')

# %%
index_col='year',parse_dates=Tru
# Out:
#   File "<ipython-input-14-48f075cc69a4>", line 1
#     index_col='year',parse_dates=Tru
#               ^
# SyntaxError: cannot assign to literal

# %%
globalResults.head(5)
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
cityResultsWindow = cityResults.avg_temp.rolling(window=10).mean()
globalResultsWindows = globalResults.avg_temp.rolling(window=10).mean()

# %%
cityResultsWindow.head(20)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9     7.938
# 10    8.130
# 11    7.985
# 12    8.435
# 13    8.317
# 14    8.300
# 15    8.504
# 16    8.436
# 17    8.403
# 18    8.382
# 19    8.331
# Name: avg_temp, dtype: float64

# %%
ma = 10
start = int(cityResults.min(axis=0)['year'])
end = int(cityResults.max(axis=0)['year'])

# %%
plt.figure(figsize = (15,8))
plt.grid(True)
plt.title('Moving Windows Comparison')
plt.plot(cityResultsWindow,label = 'Dublin')
plt.plot(globalResultsWindows, label = 'Global Temprature')
plt.xlabel('Date')
plt.ylabel('temprature')
plt.xticks(np.arange(start, end, ma))
plt.legend(loc=2)
